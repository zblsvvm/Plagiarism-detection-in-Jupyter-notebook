# %% [markdown]
# # Assignment 6
#
# ## Generating values according to a probability distribution

# %% [markdown]
# In this part of the assignment you will create a function to generate values of $x$ between 0 and 10 distributed according to
#
# $$ \frac{1}{\mathcal{N}} \left( 1 + \frac{2}{1+x^2}+ \sin(\sqrt{3 x})^2\right) $$
#
# with
#
# $$ \mathcal{N} = \int\limits_0^{10} f(x) dx \;.$$
#
# Let's first import the usual suspects:

# %%
import matplotlib.pyplot as plt
import numpy
import random

# %% [markdown]
# This defines the function:

# %%
norm = (181 + 24*numpy.arctan(10)-numpy.cos(2*numpy.sqrt(30))-2*numpy.sqrt(30)*numpy.sin(2*numpy.sqrt(30)))/12

def f(x):
    return  (1 + (2/(1+x**2)+ numpy.sin(numpy.sqrt(3*x))**2))/norm

# %% [markdown]
# This plots the function:

# %%
xs = numpy.linspace(0, 10, 200)
fs = f(xs)
plt.plot(xs, fs);
plt.ylabel('f(x)')
plt.xlabel('x')
plt.xlim(0,10)
plt.ylim(0,0.2);

# %% [markdown]
# Define a function `genSample` that generates a sample of `npts` values $x$ distributed according to $f(x)$. [5 marks]

# %%
def genSample(npts):
    sample = []
    m = 0.2
    
    while len(sample) < npts:
        x = random.uniform(0,10)
        if m*random.random() < f(x):
            sample.append(x)
    

    return numpy.array(sample)

# %%
# this test is worth 1 mark
testSample = genSample(103)
assert (testSample >= 0).all() 
assert (testSample <= 10).all()
assert len(testSample) == 103

# %% [markdown]
# ## Plotting task

# %% [markdown]
# Make a plot to show that the values generated are distributed in the right manner. The plot should have a title and axis labels. [4 marks]

# %%
ncolumbs = 100
nsample = 10000


xs = numpy.linspace(0, 10, 200)
fs = f(xs)
plt.hist(genSample(nsample), ncolumbs, density = 1);
plt.plot(xs, fs, linestyle="--" ,color = "red");
plt.title("a plot to show that the values generated are distributed in the right manner")
plt.xlabel("x")
plt.ylabel("f(x)")


plt.xlim(0,10)
plt.ylim(0,0.200)
# Out:
# (0, 0.2)

# %%
print (norm)
print (4*sum(genSample(1000000))/1000000)
# Out:
# 18.941113798515307
# 18.6585355233058
