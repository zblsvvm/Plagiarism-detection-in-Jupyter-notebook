# %% [markdown]
# # <center>Computational Physics</center>
# ---

# %% [markdown]
# ## Week 2: Numerical Integration

# %%
import numpy 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Define the function `f`, such that $\textrm{f}(x) \equiv x^{2}\sin(x)$. This is the function that we will be integrating.

# %%
def f(x):
    func = numpy.sin(x)*(x**2)
    print(func)
    return func;

# %% [markdown]
# Ensure your function works with numpy arrays:

# %%
xs=numpy.arange(0, 1, step=0.1)
assert numpy.isclose(f(xs), 
                     [0., 0.00099833, 0.00794677, 0.02659682, 0.06230693,
                      0.11985638, 0.20327129, 0.31566667, 0.4591079 , 0.6344948 ]).all()
# Out:
# [0.         0.00099833 0.00794677 0.02659682 0.06230693 0.11985638
#  0.20327129 0.31566667 0.4591079  0.6344948 ]

# %% [markdown]
# Derive the indefinite integral of $f(x)$ nalytically. Call this function $g(x)$ and implement it below. Set the constant of integration such that $g(0)=0$.

# %%
def g(x):
    ana_int = ((2*x*numpy.sin(x))+((2-(x**2))*numpy.cos(x)))-2
    print(ana_int)
    return ana_int;
g(0)
# Out:
# 0.0
# 0.0

# %% [markdown]
# Check your solution with the same numpy array:

# %%
assert g(0) == 0.
# Out:
# 0.0

# %%
assert numpy.isclose(g(xs), 
                     [0., 0.00002497, 0.00039822, 0.00200482, 0.0062869, 
                      0.01519502, 0.03112138, 0.05681646, 0.09529087, 0.1497043 ]).all()
# Out:
# [0.00000000e+00 2.49722326e-05 3.98224887e-04 2.00481823e-03
#  6.28690281e-03 1.51950219e-02 3.11213765e-02 5.68164649e-02
#  9.52908702e-02 1.49704300e-01]

# %% [markdown]
# Now, using the analytically derived indefinite integral, $g(x)$, define a function which calculates the definite integral of $f(x)$ over the interval $(x_{min},~x_{max})$.

# %%
def integrate_analytic(xmin, xmax):
    def_int =(g(xmax)-g(xmin))
    return def_int;

# %% [markdown]
# Check your analytic function:

# %%
assert numpy.isclose(integrate_analytic(xmin=0, xmax=4), 1.096591)
# Out:
# 1.0965907296271418
# 0.0

# %% [markdown]
# ## Numerical implementation

# %% [markdown]
# Create a function which calculates the definite integral of the function $f(x)$ over the interval $(x_{min},~x_{max})$ using Simpson's rule with $N$ panels.

# %%
def integrate_numeric(xmin, xmax, N):
    del_x = (xmax-xmin)/N
    simp = 0
    x = xmin 
    for i in range(0,N):
        mid = x+(del_x/2)
        simp += 4*f(mid)+2*f(x)
        x += del_x
    x += xmin*del_x
    final = (del_x/6)*(f(xmin)+f(xmax)+simp)
    return final;

# %% [markdown]
# Make sure you have implemented Simpson's rule correctly:

# %%
assert numpy.isclose(integrate_numeric(xmin=0, xmax=4, N=1), 1.6266126)
# Out:
# 3.637189707302727
# 0.0
# 0.0
# -12.108839924926851

# %%
assert numpy.isclose(integrate_numeric(xmin=0, xmax=4, N=50), 1.096591)
# Out:
# 6.398293469861466e-05
# 0.0
# 0.0017238557849604387
# 0.0005114540414027053
# 0.00794677323180245
# 0.0040785460893246975
# 0.02166628284742651
# 0.013691671282202951
# 0.04565474063245165
# 0.03221161580709046
# 0.08246188043677752
# 0.06230693476938409
# 0.13435638927294644
# 0.10639392204475769
# 0.20327129042221284
# 0.16657999166798906
# 0.29075389430613996
# 0.24461125278203583
# 0.39792102669585444
# 0.34182501395001164
# 0.5254201854514382
# 0.4591078981756944
# 0.67339721119878
# 0.5968601878193617
# 0.8414709848078962
# 0.7549669493461997
# 1.0287155859506023
# 0.9327764121863944
# 1.2336502631632893
# 1.1290859946662075
# 1.454237477553611
# 1.3421362837928057
# 1.6878891904460656
# 1.569613185497866
# 1.9314814707773824
# 1.8086583686643614
# 2.1813774018752476
# 2.0558880308102814
# 2.4334581703516465
# 2.3074199166411877
# 2.683162123196051
# 2.558908423786254
# 2.9255314837483097
# 2.805587533883851
# 3.1552663240453533
# 3.042321212765488
# 3.366785301033528
# ...

# %% [markdown]
# ## Plotting task

# %% [markdown]
# ** Task 1 **
#
# There will always be some discrepancy between a numerically calculated result and an analytically derived result. Produce a log-log plot showing the fractional error between these two results as the number of panels is varied. The plot should have labels and a title.

# %%
x0, x1 = 0, 2  # Bounds to integrate f(x) over
panel_counts = [4, 8, 16, 32, 64, 128, 256, 512, 1024]  # Panel numbers to use
result_analytic = integrate_analytic(x0, x1)  # Define reference value from analytical solution
analytic_answers = [abs(integrate_numeric(x0,x1,4)- result_analytic),abs(integrate_numeric(x0,x1,8)- result_analytic),abs(integrate_numeric(x0,x1,16)- result_analytic),abs(integrate_numeric(x0,x1,32)- result_analytic),abs(integrate_numeric(x0,x1,64)- result_analytic),abs(integrate_numeric(x0,x1,128)- result_analytic),abs(integrate_numeric(x0,x1,256)- result_analytic),abs(integrate_numeric(x0,x1,512)- result_analytic),abs(integrate_numeric(x0,x1,1024)- result_analytic)]
errors = analytic_answers
plt.loglog(panel_counts, errors)
plt.xlabel('log(number of panels)')
plt.ylabel('log(error in numerical integration)')
plt.title('A log log plot to show the error in numerical integration compared with analytic')
plt.show()
# Out:
# 2.469483380397012
# 0.0
# 0.015462747453407684
# 0.0
# 0.38342180251312546
# 0.11985638465105075
# 1.4827884677431034
# 0.8414709848078965
# 3.013456962301432
# 2.2443637198591224
# 0.0
# 3.637189707302727
# 0.0019480427091441827
# 0.0
# 0.051507074402725436
# 0.015462747453407684
# 0.22855362224236805
# 0.11985638465105075
# 0.5876504938994582
# 0.38342180251312546
# 1.1419324237816673
# 0.8414709848078965
# 1.8545009359344036
# 1.4827884677431034
# 2.6367468211129927
# 2.2443637198591224
# 3.3542078259715797
# 3.013456962301432
# 0.0
# 3.637189707302727
# 0.00024398171032179766
# 0.0
# 0.006553240901798551
# 0.0019480427091441827
# 0.03002329243949032
# 0.015462747453407684
# 0.08109428360544127
# 0.051507074402725436
# 0.16874029904850638
# 0.11985638465105075
# 0.29995100266346714
# 0.22855362224236805
# 0.47927915132445476
# 0.38342180251312546
# 0.7084697240572497
# 0.5876504938994582
# 0.9861842041534513
# 0.8414709848078965
# 1.3078309655310048
# 1.1419324237816673
# ...

# %% [markdown]
# What effect(s) does changing the number of panels used have
# on the accuracy of the numerical method? What happens if the number of panels is taken too large?

# %% [markdown]
# Increasing the number of panels to sum over increases the accuracy of numerical integration. However, if the number of panels is too high and the function is not of high order, the error will increase.

# %% [markdown]
# If the trapezium rule was being used, how would the panel
# count affect accuracy?

# %% [markdown]
# For the trapezium rule, increasing the panel count would decrease the error up to a point, at around N = 10^6, at which point the error will level off
