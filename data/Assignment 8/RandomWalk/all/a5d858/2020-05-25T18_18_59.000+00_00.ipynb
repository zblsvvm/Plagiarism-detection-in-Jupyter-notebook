# %% [markdown]
# # <center>L2 Computational Physics</center>
# ---
#
# ## Random Walks
#
# This assignment will look at some properties of random walks.

# %%
import numpy
from matplotlib import pyplot as plt

# %% [markdown]
# To do our work we will implement a walker class. When initialised a list of possible steps is populated. In one dimension it is
#
# [+s] , [-s]
#
# where s is the step size, it defaults to 1 but can be set as an argument in the constructor. In two dimensions the steps list contains
#
# [ +s , 0 ] , [ -s , 0 ] ,  [ 0 , +s ] , [ 0 , -s ]
#
# At each step the current position of the walker, saved in `self.pos`, is updated by adding one of the possible steps. The function `pickStep` chooses randomly one of the possible steps. Use this function to implement the `doSteps` function that performs `n` steps and returns a `(n+1) x ndim` array representing the trajectory of the walker, including the starting point.

# %%
class walker:
    def __init__(self,x0,ndim=1, step_size=1.0):
        self.pos=x0
        self.ndim=ndim
        self.possibleSteps=[]
        for i in range(ndim):
            step=numpy.zeros(ndim)
            step[i]= - step_size
            self.possibleSteps.append(numpy.array(step,dtype='f'))
            step[i]= + step_size
            self.possibleSteps.append(step.copy())
        self.npossible=len(self.possibleSteps)

    def pickStep(self):
        istep = numpy.random.choice(range(self.npossible))
        return self.possibleSteps[istep]
        
    def doSteps(self,n):
        positions=numpy.ndarray((n+1,self.ndim),dtype='f')
        positions[0] = self.pos
        for i in range(1, n+1):
            positions[i] = positions[i-1] + self.pickStep()
        
    
        # iYOUR CODE HERE
        return positions

# %%
# this test is worth 2 marks
numpy.random.seed(1111)
w = walker(numpy.zeros(1))
pos_test = w.doSteps(10)
reference = [[ 0.], [-1.], [ 0.], [ 1.], [ 2.], [ 1.], [ 0.], [-1.], [-2.], [-3.], [-4.]]
assert len(pos_test)==11
# plots to help debugging
plt.plot(range(11),pos_test, label='your trajectory')
plt.plot(range(11),reference,'o', label='reference points')
plt.legend()
plt.xlabel('step number')
assert (pos_test == reference).all()

# %%
# this test is worth 5 marks
numpy.random.seed(1112)
w = walker(numpy.zeros(2), ndim=2)
pos_test = w.doSteps(10)
reference = numpy.array([[ 0.,  0.], [-1.,  0.], [-1., -1.], [-2., -1.], 
             [-2.,  0.], [-2.,  1.], [-1.,  1.], [-1.,  2.], 
             [ 0.,  2.], [ 1.,  2.], [ 0.,  2.]])
assert pos_test.shape == (11,2)
# plots to help debugging
plt.plot(pos_test[:,0], pos_test[:,1],'-o', label='your trajectory')
plt.plot(reference[:,0],reference[:,1],'o', label='reference points')
plt.legend()
assert (pos_test == reference).all()

# %% [markdown]
# This is a plot to visualise trajectories. Use it to convince yourself that you get different trajectories.

# %%
nsteps = 100
for i in range(10):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    plt.plot(range(nsteps+1),ys)

# %% [markdown]
# **Task 1**
#
# Make a plot of average position and average squared position of 100 1D walkers using 1000 steps. Your plot needs a legend, title and labels. [5 marks]

# %%
array=[]

for i in range(100):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    array.append(ys)

       

nsteps = 1000
ndim = 1    

array_2=[]
A, = plt.plot(range(nsteps+1), numpy.mean(array, axis= 0), label = 'avg position')
for i in range(100):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    array_2.append(ys**2)

B, = plt.plot(range(nsteps+1), numpy.mean(array_2, axis=0), label = 'avg squared position')
plt.xlabel('Number of Steps')
plt.ylabel('Averages')
plt.title('Plot to show average position and average squared position of 100 1D walkers using 1000 steps')
plt.legend(handles=[A, B])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1ac5c305d775> in <module>()
#      13
#      14 array_2=[]
# ---> 15 A, = plt.plot(range(nsteps+1), numpy.mean(array, axis= 0), label = 'avg position')
#      16 for i in range(100):
#      17     w = walker(numpy.zeros(1))
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1001,) and (101, 1)

# %% [markdown]
# **Task 2**
#
# Make a plot to show that the average squared distance scaling is independent of the dimension in which the walker moves. Use 100 steps and 400 walkers and use $D=1,2,3,4$. The plot should have a title, legend and labels. [5 marks]

# %%
nsteps = 100    
nwalkers = 400   
toty=[]                                             
totysq=[]

toty2=[]
totysq2=[]
totmag2 =[]

toty3=[]
totysq3=[]
totmag3 =[]

toty4=[]
totysq4=[]
totmag4 =[]
for i in range(nwalkers):
    w = walker(numpy.zeros(1), ndim=1)
    ys = w.doSteps(nsteps)
    toty.append(ys)
for i in toty:
    ysquared = i**2
    totysq.append(ysquared)
    yavsq = numpy.average(totysq, axis = 0)

plt.plot(range(nsteps+1),yavsq, label =  '1 dimension')
#plt.legend()


for i in range(nwalkers):
    w = walker(numpy.zeros(2), ndim=2)
    ys = w.doSteps(nsteps)
    toty2.append(ys)

for i in toty2:
    ysquared = i**2
    totysq2.append(ysquared)
    yavsq2 = numpy.average(totysq2, axis = 0)
    ##print(i)
for j in range(nsteps+1):
    valmag = yavsq2[j][0] + yavsq2[j][1]
    totmag2.append(valmag)
plt.plot(range(nsteps+1),totmag2, label =  '2 dimension')



for i in range(nwalkers):
    w = walker(numpy.zeros(3), ndim=3)
    ys = w.doSteps(nsteps)
    toty3.append(ys)
    
for i in toty3:
    ysquared = i**2
    totysq3.append(ysquared)
    yavsq3 = numpy.average(totysq3, axis = 0)
    
for j in range(nsteps+1):
    valmag = yavsq3[j][0] + yavsq3[j][1] + yavsq3[j][2]
    totmag3.append(valmag)
plt.plot(range(nsteps+1),totmag3, label =  '3 dimension')



for i in range(nwalkers):
    w = walker(numpy.zeros(4), ndim=4)
    ys = w.doSteps(nsteps)
    toty4.append(ys)

for i in toty4:
    ysquared = i**2
    totysq4.append(ysquared)
    yavsq4 = numpy.average(totysq4, axis = 0)
    
for j in range(nsteps+1):
    valmag = yavsq4[j][0] + yavsq4[j][1] + yavsq4[j][2] + yavsq4[j][3]
    totmag4.append(valmag)
plt.plot(range(nsteps+1),totmag4, label =  '4 dimension')
plt.legend()
plt.xlabel('number of steps')
plt.title('A Plot to Show that the Average Squared Distance Scaling is Independent of the Dimension')
plt.ylabel('position squared')

# %% [markdown]
# ## 2D walkers

# %% [markdown]
# Use 1000 walkers randomly distributed in the unit square (the positions are given in the array `rand_pos`) simulate the diffusion of particles with step size 0.05. Make a plot of the position of the walkers after 10, 100 and 500 steps. The plots should have labels and titles.
#
# Tip: Use `plt.scatter` and consider using its `alpha` option to make you plot look nicer. [6 marks]

# %%
ndim=2
nwalkers=1000  #500

rand_pos = numpy.random.uniform(size=(nwalkers, ndim))

#print(rand_pos)
#this code is a template to create 3 subplots in one, adapt it to your task!
plt.figure(figsize=(18,6))
pos10=[0]*1000
pos100=[0]*1000
pos500=[0]*1000


plt.subplot(131)    
plt.xlabel('x')
plt.ylabel('y')
plt.xlim((-3, 4))
plt.ylim((-3, 4))
plt.title('Particles after 10 steps')
for j in range(len(rand_pos)):
    w = walker(rand_pos[j], ndim=2, step_size=0.05)
    newpos500 = w.doSteps(500)
    pos10[j] = newpos500[9]
    pos100[j] = newpos500[99]
    pos500[j] = newpos500[499]
    plt.scatter(pos10[j][0],pos10[j][1],  alpha = 0.3)
    
    
plt.subplot(132)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim((-3, 4))
plt.ylim((-3, 4))
plt.title('particles after 100 steps')
for k in range(len(rand_pos)):
    plt.scatter(pos100[k][0], pos100[k][1], alpha = 0.3)

plt.subplot(133)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim((-3, 4))
plt.ylim((-3, 4))
plt.title('particles after 500 steps')
for g in range(len(rand_pos)):
    plt.scatter(pos500[g][0],pos500[g][1],  alpha = 0.3)
