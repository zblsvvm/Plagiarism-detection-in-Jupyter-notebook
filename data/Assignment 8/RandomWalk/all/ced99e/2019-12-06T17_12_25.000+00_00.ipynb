# %% [markdown]
# # <center>L2 Computational Physics</center>
# ---
#
# ## Random Walks
#
# This assignment will look at some properties of random walks.

# %%
import numpy
from matplotlib import pyplot as plt

# %% [markdown]
# To do our work we will implement a walker class. When initialised a list of possible steps is populated. In one dimension it is
#
# [+s] , [-s]
#
# where s is the step size, it defaults to 1 but can be set as an argument in the constructor. In two dimensions the steps list contains
#
# [ +s , 0 ] , [ -s , 0 ] ,  [ 0 , +s ] , [ 0 , -s ]
#
# At each step the current position of the walker, saved in `self.pos`, is updated by adding one of the possible steps. The function `pickStep` chooses randomly one of the possible steps. Use this function to implement the `doSteps` function that performs `n` steps and returns a `(n+1) x ndim` array representing the trajectory of the walker, including the starting point.

# %%
class walker:
    def __init__(self,x0,ndim=1, step_size=1.0):
        self.pos=x0
        self.ndim=ndim
        self.possibleSteps=[]
        for i in range(ndim):
            step=numpy.zeros(ndim)
            step[i]= - step_size
            self.possibleSteps.append(numpy.array(step,dtype='f'))
            step[i]= + step_size
            self.possibleSteps.append(step.copy())
        self.npossible=len(self.possibleSteps)

    def pickStep(self):
        istep = numpy.random.choice(range(self.npossible))
        return self.possibleSteps[istep]
        
    def doSteps(self,n):
        positions=numpy.ndarray((n+1,self.ndim),dtype='f')
        positions[0] = self.pos
        for i in range(1, n+1):
            positions[i]= self.pickStep() + positions[i-1]
        
        return positions

# %%
# this test is worth 2 marks
numpy.random.seed(1111)
w = walker(numpy.zeros(1))
pos_test = w.doSteps(10)
reference = [[ 0.], [-1.], [ 0.], [ 1.], [ 2.], [ 1.], [ 0.], [-1.], [-2.], [-3.], [-4.]]
assert len(pos_test)==11
# plots to help debugging
plt.plot(range(11),pos_test, label='your trajectory')
plt.plot(range(11),reference,'o', label='reference points')
plt.legend()
plt.xlabel('step number')
assert (pos_test == reference).all()

# %%
# this test is worth 5 marks
numpy.random.seed(1112)
w = walker(numpy.zeros(2), ndim=2)
pos_test = w.doSteps(10)
reference = numpy.array([[ 0.,  0.], [-1.,  0.], [-1., -1.], [-2., -1.], 
             [-2.,  0.], [-2.,  1.], [-1.,  1.], [-1.,  2.], 
             [ 0.,  2.], [ 1.,  2.], [ 0.,  2.]])
assert pos_test.shape == (11,2)
# plots to help debugging
plt.plot(pos_test[:,0], pos_test[:,1],'-o', label='your trajectory')
plt.plot(reference[:,0],reference[:,1],'o', label='reference points')
plt.legend()
assert (pos_test == reference).all()

# %% [markdown]
# This is a plot to visualise trajectories. Use it to convince yourself that you get different trajectories.

# %%
nsteps = 100
for i in range(10):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    plt.plot(range(nsteps+1),ys)

# %% [markdown]
# **Task 1**
#
# Make a plot of average position and average squared position of 100 1D walkers using 1000 steps. Your plot needs a legend, title and labels. [5 marks]

# %%
nsteps = 1000
ndim = 1
nwalkers = 100
total_walkers=[]
average_walk=[]
average_walk_squared=[]
for i in range(1000):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    avg_walk = numpy.sum(ys[i])/nwalkers
    average_walk.append(avg_walk)
#     avg_squared = numpy.sum(ys[i]**2)/nwalkers
#     average_walk_squared.append(avg_squared)
    
    


plt.plot(range(nsteps), average_walk,'k', label='average')
# plt.plot(range(nsteps), average_walk_squared,'r', label='average squared')
plt.xlabel('Steps')
plt.ylabel('Position')
plt.legend(loc='upper left')
plt.title('A graph of average position and average position squared of 100 1D walkers using 1000 steps')
# Out:
# Text(0.5,1,'A graph of average position and average position squared of 100 1D walkers using 1000 steps')

# %% [markdown]
# **Task 2**
#
# Make a plot to show that the average squared distance scaling is independent of the dimension in which the walker moves. Use 100 steps and 400 walkers and use $D=1,2,3,4$. The plot should have a title, legend and labels. [5 marks]

# %%
nsteps = 100
nwalkers = 400
dimensions = range(1,5)

average_walk_1 =[]
average_walk_squared_1=[]
ndim = 1
for i in range(nsteps):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    avg_walk_1 = numpy.sum(ys[i])/nwalkers
    average_walk_1.append(avg_walk_1)
    avg_squared_1 = (numpy.sum(ys[i])/nwalkers)**2
    average_walk_squared_1.append(avg_squared_1)
    
    
plt.plot(range(nsteps), average_walk_squared_1, label='D=1')

average_walk_2 =[]
average_walk_squared_2=[]
ndim = 2
for i in range(nsteps):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    avg_walk_2 = numpy.sum(ys[i])/nwalkers
    average_walk_2.append(avg_walk_2)
    avg_squared_2 = (numpy.sum(ys[i])/nwalkers)**2
    average_walk_squared_2.append(avg_squared_2)
    
    
plt.plot(range(nsteps), average_walk_squared_2, label='D=2')

average_walk_3 =[]
average_walk_squared_3=[]
ndim = 3
for i in range(nsteps):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    avg_walk_3 = numpy.sum(ys[i])/nwalkers
    average_walk_3.append(avg_walk_3)
    avg_squared_3 = (numpy.sum(ys[i])/nwalkers)**2
    average_walk_squared_3.append(avg_squared_3)
    
    
plt.plot(range(nsteps), average_walk_squared_3,label='D=3')

average_walk_4 =[]
average_walk_squared_4=[]
ndim = 4
for i in range(nsteps):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    avg_walk_4 = numpy.sum(ys[i])/nwalkers
    average_walk_4.append(avg_walk_4)
    avg_squared_4 = (numpy.sum(ys[i])/nwalkers)**2
    average_walk_squared_4.append(avg_squared_4)
    
    
plt.plot(range(nsteps), average_walk_squared_4, label='D=4')

average_walk_5 =[]
average_walk_squared_5=[]
ndim = 5
for i in range(nsteps):
    w = walker(numpy.zeros(1))
    ys = w.doSteps(nsteps)
    avg_walk_5 = numpy.sum(ys[i])/nwalkers
    average_walk_5.append(avg_walk_5)
    avg_squared_5 = (numpy.sum(ys[i])/nwalkers)**2
    average_walk_squared_5.append(avg_squared_5)
    
    
plt.plot(range(nsteps), average_walk_squared_5, label='D=5')

plt.xlabel('Steps')
plt.ylabel('Position')
plt.legend(loc='upper left')

# %% [markdown]
# ## 2D walkers

# %% [markdown]
# Use 1000 walkers randomly distributed in the unit square (the positions are given in the array `rand_pos`) simulate the diffusion of particles with step size 0.05. Make a plot of the position of the walkers after 10, 100 and 500 steps. The plots should have labels and titles.
#
# Tip: Use `plt.scatter` and consider using its `alpha` option to make you plot look nicer. [6 marks]

# %%
ndim=2
nwalkers=1000
step_size = 0.05
nsteps_1 = 10
nsteps_2 = 100
nsteps_3 = 500

rand_pos = numpy.random.uniform(size=(nwalkers, ndim))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-af05e62b6bd4> in <module>()
#      13 for i in range(10):
#      14     w = walker(numpy.random.uniform(size=(nwalkers, ndim)))
# ---> 15     ys = w.doSteps(nsteps)
#      16     plt.scatter(range(nsteps+1),ys,)
#      17
#
# <ipython-input-84-3bca8ecba4b2> in doSteps(self, n)
#      28     def doSteps(self,n):
#      29         positions=numpy.ndarray((n+1,self.ndim),dtype='f')
# ---> 30         positions[0] = self.pos
#      31         for i in range(1, n+1):
#      32             positions[i]= self.pickStep() + positions[i-1]
#
# ValueError: could not broadcast input array from shape (1000,2) into shape (2)
