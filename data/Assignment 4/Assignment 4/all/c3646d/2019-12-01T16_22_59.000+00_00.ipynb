# %% [markdown]
# # <center>L2 Computational Physics</center>
# ---
# ## Week 4: Differential Equations II

# %% [markdown]
# In this notebook, you will write a program to study the trajectory of a spherical, iron cannonball in the presence of gravity and drag forces.

# %%
import numpy
from matplotlib import pyplot as plt

# %%
# Define all constants to be used in the simulation
r_cb = 0.15  # Radius of cannonball in m
rho_iron = 7874  # Density of iron in kg/m^3
g = 9.81  # Acceleration due to gravity in m/s^2
kappa = 0.47  # Drag coefficient of a sphere
rho_air = 1.23  # Density of air in kg/m^3
v0 = 125.00  # Initial speed in m/s

# %% [markdown]
# From this information, calculate the following two variables:

# %%
def get_area(r):
    ''' 
    This function returns the cross section area of a sphere of radius r. The returned 
    value is in the squared units of the unit of the radius argument.
    '''
    # YOUR CODE HERE
    return numpy.pi*r**2

def get_mass(r):
    ''' 
    This function returns the mass of an iron sphere of radius r. The radius 
    should be given in meter and the return value is in kg.
    '''
    # YOUR CODE HERE
    return rho_iron*(4/3)*numpy.pi*r**3

area_cb = get_area(r_cb)
mass_cb = get_mass(r_cb)

# %%
# these tests are worth one mark
assert numpy.isclose(area_cb, 0.07068583470577035)
assert numpy.isclose(mass_cb, 111.31605249464711)

# %% [markdown]
# ## The Differential Equations

# %% [markdown]
# Create a function `f` which calculates the right-hand side of the differential equation
#
# $$ \frac{d}{dt}\left(\begin{array}{c}x\\y\\v_x \\v_y \end{array}\right) = f(x, y, v_x, v_y, t)$$
#
# such that the differential equation represents the cannonball's motion as it moves through the air.
#
# - *Your function should accept two arguments:*
#     - `r` *- a numpy array representing the cannonball's state, $(x, y, v_{x}, v_{y})$.*
#     - `t` *- Time *
#
# - *The drag force experienced by the cannonball is given by $$\vec{F}_{\textrm{d}} = - \frac{1}{2} C_{\textrm{d}} \rho |\vec{v}|^{2} A \widehat{v}~,$$ where $\widehat{v}$ is a unit vector pointing in the direction of the cannonball's instantaneous velocity.*

# %%
dx_dt = 0
dy_dt = 0
def f(r, t):
    '''Implements differential equation for cannonball from state vector r and time t'''
    
    # Unpack array of the state
    x, y, vx, vy = r
    
    v = [vx,vy]/numpy.sqrt(vx**2 + vy**2)
  
    # these variables should updated in your code to be the derivatives of 
    # the x, y positions and the derivative of the x, y velocities. 
    dx_dt, dy_dt, dvx_dt, dvy_dt = vx,vy,0,0

    dvx_dt = (-0.5*kappa*rho_air*(vx**2 + vy**2)*area_cb*v[0]/mass_cb)
    dvy_dt = -g + (-0.5*kappa*rho_air*(vx**2 + vy**2)*area_cb*v[1]/mass_cb)
    dx_dt = vx + dvx_dt*t
    dy_dt = vy + dvy_dt*t
    
    # YOUR CODE HERE
    return numpy.array([dx_dt, dy_dt, dvx_dt, dvy_dt])

r_test = [0, 0, 88.38834764831843, 88.38834764831843]

f(r_test, 0)
# Out:
# array([ 88.38834765,  88.38834765,  -2.0279283 , -11.8379283 ])

# %% [markdown]
# Check your result:

# %%
r_test = [0, 0, 88.38834764831843, 88.38834764831843]
assert len(f(r_test, 0))== 4

# %%
r_test = [0, 0, 88.38834764831843, 88.38834764831843]
assert numpy.isclose(f(r_test, 0), [ 88.38834765,  88.38834765,  -2.0279283 , -11.8379283 ]).all()

# %% [markdown]
# ## Solving the Differential Equations

# %% [markdown]
# Create the function `solve_euler(state_initial, t1, n_panels)` which solves the differential equations using Euler's method.
#
# - `state_initial` *is a numpy array containing the initial conditions $(x_{0}, y_{0}, v_{x0}, v_{y0})$*
# - *When working with a numpy array, you can use the same commands as those used for single variables - for instance,* `state += f(state, t)`.
# - *This function should record all state values at each timepoint in the variable `history` and return it. This will be similar to last week, only this time you will have to populate a 2D array.*

# %%
def solve_euler(state_initial, t1, n_steps):
    '''Solves ODE using Euler's method from state_initial to end time t1 using n_panels panels'''
    # Define array for trajectory history
    history = numpy.empty((n_steps+1,4))  # Number of columns is equal to number of variables to solve for (4)
    history[0] = state_initial
    # you should now populate the history array
    # YOUR CODE HERE
    
    dt = t1/n_steps
    initial = state_initial
    for i in range(0, n_steps):
        derivs = f(initial, 0)
        initial = initial + derivs*dt
        history[i+1] = (initial)
    return history

r_test = [0, 0, 88.388, 88.388]

print(solve_euler(r_test, 25.0, 10))
# Out:
# [[   0.            0.           88.388        88.388     ]
#  [ 220.97        220.97         83.31821913   58.79321913]
#  [ 429.26554783  367.95304783   79.41956841   31.51714946]
#  [ 627.81446887  446.74592148   76.30569982    5.75643055]
#  [ 818.57871841  461.13699786   73.62632279  -18.97069914]
#  [1002.64452539  413.71025001   71.05763241  -42.83384546]
#  [1180.28860641  306.62563636   68.35232645  -65.72807544]
#  [1351.16942255  142.30544777   65.37809783  -87.39303637]
#  [1514.61466712  -76.17714317   62.10386729 -107.54126559]
#  [1669.87433534 -345.03030714   58.5648982  -125.93806083]
#  [1816.28658082 -659.87545921   54.8324498  -142.43679718]]

# %% [markdown]
# Test your solution:

# %%
# this test is worth 4 marks
r_test = [0, 0, 88.38834764831843, 88.38834764831843]
assert numpy.isclose(solve_euler(r_test, 25.0, 10), numpy.array(
    [[   0.        ,    0.        ,   88.38834765,   88.38834765],
     [ 220.97086912,  220.97086912,   83.3185269 ,   58.7935269 ],
     [ 429.26718637,  367.95468637,   79.41984538,   31.51743125],
     [ 627.81679983,  446.7482645 ,   76.30595276,    5.75669607],
     [ 818.58168171,  461.14000469,   73.62655732,  -18.97044366],
     [1002.64807501,  413.71389553,   71.05785323,  -42.83359748],
     [1180.2927081 ,  306.62990184,   68.35253688,  -65.72783569],
     [1351.1740503 ,  142.31031262,   65.37829955,  -87.3928075 ],
     [1514.61979917,  -76.17170612,   62.10406078, -107.54105068],
     [1669.87995113, -345.02433282,   58.56508321, -125.93786257],
     [1816.29265915, -659.86898925,   54.83262575, -142.43661744]])).all()

# %% [markdown]
# ## Finding the range
#
# To find the range of the projectile we will look for the $x$ coordinate when the trajectory crosses the $y=0$ line. In most cases that point will not be one of the steps but will be between two steps. We will use a linear approximation to determine this point given the last point with a positive $y$ value and the first point with a negative $y$ value. Implement the function `find_zero_linear` that takes as argument the two values of $x$ `x1` and `x2` and the heights `y1` and `y2` and returns the value of $x$ at which the line between $(x_1,y_1)$ and $x_2,y_2$ crosses the $y=0$ line.

# %%
def find_zero_linear(x1, x2, y1, y2):
    delta_y = y2 - y1
    delta_x = x2 - x1
    if y1*y2 > 0:
        print("I expect y1 and y2 to have opposite signs!")
    # YOUR CODE HERE
    else:
        m = delta_y/delta_x
        intercept = y1 - m*x1
        x = -intercept/m
    return x

# %%
# these tests are worth 2 marks
assert numpy.isclose(find_zero_linear(-1,1,3,-3),0.0)
assert numpy.isclose(find_zero_linear(-1,1,1,-3), -0.5)

# %% [markdown]
# Given the function above we can define a function to determine the range. (Don't modify it!)

# %%
def find_range(history):
    all_xs = history[:,0]
    all_ys = history[:,1]
    negatives = numpy.argwhere(all_ys<0)
    if len(negatives) == 0 :
        print ("The projectile did not touch down! Returning the last known location")
        return all_xs[-1]
    (index,) = negatives[0]
    y1, y2 = all_ys[index-1], all_ys[index]
    x1, x2 = all_xs[index -1], all_xs[index]
    return find_zero_linear(x1,x2,y1,y2)

r_test = [0, 0, 88.38834764831843, 88.38834764831843]
h = solve_euler(r_test, 25.0, 10000)
print(find_range(h))
# Out:
# 1306.254091067471

# %%
r_test = [0, 0, 88.38834764831843, 88.38834764831843]
h = solve_euler(r_test, 25.0, 10000)
assert numpy.isclose(find_range(h),1306.2541)

# %% [markdown]
# ## Plotting task

# %% [markdown]
# Create a plot to show the trajectories for different values of the initial angle. Use the same velocity $v0=125\rm{m/s}$ for all angles. The plot should have axis labels and a title. [4 marks]

# %%
n_steps = 1000
thetas = range(1, 90, 1) # the angles in degrees]
v_0 = 125 #m/s

initial_conditions = [0, 0, 88.38834764831843, 88.38834764831843]    
values_euler = solve_euler(initial_conditions, 300, n_steps)
plt.xlim(0,1500)
plt.ylim(0,800);
plt.xlabel('Distance Travelled in x-axis')
plt.ylabel('Distance Travelled in y-axis')
plt.title('Trajectories Taken for Different Initial Angles')

for i in thetas:
    initial_conditions = [0, 0, v_0*numpy.cos(i*numpy.pi/180), v_0*numpy.sin(i*numpy.pi/180)]
    values_euler = solve_euler(initial_conditions, 300, n_steps)
    xs_euler = values_euler[:,0]
    ys_euler = values_euler[:,1]
    plt.plot(xs_euler, ys_euler, linestyle = '--')

# %% [markdown]
# Create a plot to show the range for different values of the initial velocity. Use the same angle $\theta=60^\circ$ for all velocities. The plot should have axis labels and a title and legend. Produce one curve with and one curve without the effect of air resistance. [5 marks]

# %%
n_steps = 1000
max_time = 300
v0s = numpy.linspace(50, 1000, 20)

ranges = numpy.array([])
ranges_noresistance = []
theta = numpy.deg2rad(60)

# Your code here
for i in v0s:
    state = [0, 0, i*numpy.cos(theta), i*numpy.sin(theta)]
    history = solve_euler(state, max_time, n_steps)
    air_resistance_range = find_range(history)
    ranges = numpy.append(ranges, air_resistance_range)

for i in v0s:   
    ranges_noresistance.append(((i**2)/g)*numpy.sin(2*theta))

plt.plot(v0s, ranges, label = 'Air Resistance')
plt.plot(v0s, ranges_noresistance, label = 'No Air Resistance')
plt.xlabel('Starting Velocity / m/s')
plt.ylabel('Projectile Range / m')
plt.legend()
plt.title('How Initial Velocity Changes with Range')
plt.show()
