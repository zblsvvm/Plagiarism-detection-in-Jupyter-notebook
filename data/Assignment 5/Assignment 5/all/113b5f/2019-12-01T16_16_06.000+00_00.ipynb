# %% [markdown]
# # <center>L2 Computational Physics</center>
# ---
#
# ## Week 5: Monte Carlo Methods
#
# In this notebook, you will simulate a system with of three nuclei $A$, $B$ and $C$ where $A$ decays into $B$ and $B$ decays into $C$. If exposed to a neutron flux nucleus $C$ can be activated into a nucleus $A$.

# %%
import numpy
from matplotlib import pyplot as plt
import random

# %% [markdown]
# Implement a function that tells whether a transition has occured, based on the transition probability and a random number. Use the random number `r` from `random.random()` and use the procedure described in the notes so that the checks can work in a reproducible way.

# %%
def has_transitioned(prob):
    r = random.random()
    if r<prob:
        return True
    else:
        return False

# %%
# this test is worth 1 mark
random.seed(9867)
assert [ has_transitioned(0.5) for i in range(10)] == [False, False, True, False, False, False, False, True, False, True]

# %% [markdown]
# We are going to keep track of the state of the atoms using a either `'A'`, `'B'` or `'C'` for each nucleus. For example
# ```python
# state = ['A', 'A', 'B', 'A', 'C']
# ```
#
# We will capture the possible physical reaction in a list of allowed transitions such as
#
# `('A', 'B', 0.25 )`
#
# where the first element is the initial state, the second element is the final state of the transition and its probability in the time interval considered is the third argument.
#
# Define a function that takes as arguments the current state and a list of such transition rules and implements the transition (or not) and returns the new state

# %%
def evolveOne(currentState, rules):
    for i in currentState:
        probAB = rules[0][2]
        probBC = rules[1][2]
        if i=='A':
            x=has_transitioned(probAB)
            if x==True:
                return 'B'
            else:
                return 'A'
        if i=='B':
            r=has_transitioned(probBC)
            if r==True:
                return 'C'
            else:
                return 'B'
        if i=='C':
            if len(rules)==3:
                probCA = rules[2][2]
                t=has_transitioned(probCA)
                if t==True:
                    return 'A'
                if t==False:
                    return 'C'
            else:
                return 'C'

# %%
# these tests are worth 1 mark
alwaysDecayRules = [
    ('A', 'B', 1.0),
    ('B', 'C', 1.0)
]
assert evolveOne('A', alwaysDecayRules) == 'B'
assert evolveOne('B', alwaysDecayRules) == 'C'

# %%
# these tests are worth 2 mark
random.seed(112211)
testRules = [
    ('A', 'B', 0.33),
    ('B', 'C', 0.75)
]
assert evolveOne('A', testRules) == 'A'
assert evolveOne('A', testRules) == 'A'
assert evolveOne('A', testRules) == 'A'
assert evolveOne('A', testRules) == 'A'
assert evolveOne('A', testRules) == 'B'

assert evolveOne('B', testRules) == 'B'
assert evolveOne('B', testRules) == 'C'
assert evolveOne('B', testRules) == 'C'
assert evolveOne('B', testRules) == 'C'
assert evolveOne('B', testRules) == 'C'

# with no rules there should be no change
assert evolveOne('C', testRules) == 'C'

# %% [markdown]
# Now implement a function that takes a list of states and transition them according to the rules passed as argument. This function should return a new vector of states, it should not modify the state passed as an argument!

# %%
def evolveMany(states, rules):
    newState = []
    for i in states:
        w = evolveOne(i, rules)
        newState.append(w)
    return newState

# %%
# these tests are worth 1 mark
random.seed(112287)
testRules = [
    ('A', 'B', 0.33),
    ('B', 'C', 0.75)
]
initialTestArray = ['A','B','C']*5
evolvedTest = evolveMany(initialTestArray, testRules)
targetArray = ['B', 'C', 'C', 'A', 'C', 'C', 'A', 'B', 'C', 'A', 'C', 'C', 'B', 'C', 'C'] 
assert evolvedTest == targetArray
# checks the initial array is left unchanged
assert initialTestArray == ['A','B','C']*5

# %% [markdown]
# Define a function that evolves a system that starts with initial amounts `NA`, `NB` and `NC` of $A$, $B$ and $C$ nuclei and evolved it in `n_timestep` from time $t=0$ to $t=t_{max}$. The function should return three arrays, one for each atom type, of the number of nuclei of that type at each time step. Each array should contain `n_timestep+1` elements including the initial amount.

# %%
def evolve_system(NA, NB, NC, rules, n_step):
    state_initial = (['A'] * NA)+(['B'] * NB)+(['C'] * NC)

    A_count = numpy.empty(n_step + 1, dtype=int)
    B_count = numpy.empty(n_step + 1, dtype=int)
    C_count = numpy.empty(n_step + 1, dtype=int)
    
    A_count[0] = NA
    B_count[0] = NB
    C_count[0] = NC
    
    state = numpy.zeros((n_step+1, (NA+NB+NC)), dtype=object)
    
    state[0]=state_initial
    
    
    for i in range (1,n_step+1):
        state[i]=evolveMany(state[i-1],rules)
    
    for i in range (1,len(state)):
        A_count[i] = numpy.count_nonzero(state[i]=='A')
        B_count[i] = numpy.count_nonzero(state[i]=='B')
        C_count[i] = numpy.count_nonzero(state[i]=='C')
    return A_count, B_count, C_count

# %%
# these tests are worth 2 marks
rules = [
    ('A', 'B', 0.0033),
    ('B', 'C', 0.0075),
    ('C', 'A', 0.009)
    
]

r1, r2, r3 = evolve_system(0,0,250, rules, 17)
assert len(r1) == 18
assert len(r2) == 18
assert len(r3) == 18

# %%
# these tests are worth 2 marks 
testrules = [
    ('A', 'B', 0.086),
    ('B', 'C', 0.075),
    ('C', 'A', 0.19)
    
]

random.seed(9485)
r1, r2, r3 = evolve_system(200,200,200, testrules, 20)
assert (r1 == [200, 213, 233, 250, 258, 251, 266, 263, 259, 260, 265, 259, 256,
        255, 258, 256, 259, 253, 249, 247, 253]).all()
assert (r2 == [200, 198, 201, 206, 205, 214, 214, 212, 216, 221, 225, 234, 236,
        238, 234, 235, 231, 245, 253, 256, 252]).all()
assert (r3 == [200, 189, 166, 144, 137, 135, 120, 125, 125, 119, 110, 107, 108,
        107, 108, 109, 110, 102,  98,  97,  95]).all()

# %% [markdown]
# ## Plotting tasks

# %% [markdown]
# Create a plot with the number of $A$, $B$ and $C$ nuclei, starting with 250 $C$ nuclei and evolving the system for 100 hours using 200 steps and with neutron flux on. Evolve the system for another 100 hours (using 200 steps) without neutron flux (i.e. no transitions from $C$ to $A$).
#
# The half life of the $A$ atoms is 10.1 hours, the half life of $B$ nuclei is 15.7 hours and we can caracterise the rate of activation of $C$ into $A$ when the neutron flux is on with and effective half-life of 3.2 hours.
#
# The plot should have the appropriate labels and legend. [8 marks]

# %%
nsteps = 200
t_total = 100
t_half_A = 10.1
t_half_B = 15.7
t_half_C = 3.2
DecayA = numpy.log(2)/(t_half_A)
DecayB = numpy.log(2)/(t_half_B)
DecayC = numpy.log(2)/(t_half_C)
t=[]
for i in range (0,402):
    l=0.5*i
    t.append(l)
pA=numpy.exp(-DecayA*0.5)
pB=numpy.exp(-DecayB*0.5)
pC=numpy.exp(-DecayC*0.5)
rule1= [('A', 'B',1-pA), ('B', 'C',1-pB), ('C', 'A',1-pC)]
rule2= [('A', 'B',1-pA), ('B', 'C',1-pB)]

A1=evolve_system(0,0,250,rule1,200)[0]
B1=evolve_system(0,0,250,rule1,200)[1]
C1=evolve_system(0,0,250,rule1,200)[2]

A2=evolve_system(A1[200],B1[200],C1[200], rule2, 200)[0]
B2=evolve_system(A1[200],B1[200],C1[200], rule2, 200)[1]
C2=evolve_system(A1[200],B1[200],C1[200], rule2, 200)[2]

A = numpy.concatenate((A1,A2), axis=0)
B = numpy.concatenate((B1,B2), axis=0)
C = numpy.concatenate((C1,C2), axis=0)

plt.figure(figsize=(9.6,6.4), dpi=100, frameon=True)
plt.plot(t,A, label='A', color='fuchsia')
plt.plot(t,B, label='B', color='xkcd:green')
plt.plot(t,C, label='C', color='blue')
plt.legend()
plt.xlabel('Time /h', size=10, labelpad=15)
plt.ylabel('Count', size=10, labelpad=15)
plt.title('Count of Nuclei Over A 200 Hour Period', size=13, pad=15)
# Out:
# Text(0.5,1,'Count of Nuclei Over A 200 Hour Period')

# %% [markdown]
# Run the above simulation 20 times with 200 steps and use the results to calculate an average and the uncertainty on the number of $A$ atoms as a function of time. Use and `errorbar` plot for it. You might be interested in the `numpy.average` and `numpy.std` functions. The plot should have axis labels and a title.  [3 marks]

# %%
t=[]
for i in range (0,402):
    l=0.5*i
    t.append(l)
nsim = 20
X=[]
for i in range (0,nsim):
    A1=evolve_system(0,0,250,rule1,200)[0]
    A2=evolve_system(A1[200],B1[200],C1[200], rule2, 200)[0]
    A = numpy.concatenate((A1,A2), axis=0)
    X.append(A)
plt.figure(figsize=(9.6,6.8), dpi=100)
avg=numpy.mean(X, axis=0)
std=numpy.std(X, axis=0)
error=std/numpy.sqrt(20)
plt.errorbar(t,avg,xerr=0, yerr=error, capsize=1, ecolor='red', elinewidth=0.5)
plt.xlabel('Time /h', size=10, labelpad=15)
plt.ylabel('Mean Count', size=10, labelpad=15)
plt.title('Mean Count of Nucleus $A$ Over A 200 Hour Period', size=13, pad=15)
# Out:
# Text(0.5,1,'Mean Count of Nucleus $A$ Over A 200 Hour Period')
